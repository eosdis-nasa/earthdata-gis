# %%
import nbformat

nb = nbformat.read("TEMPO_Image_Service_Programmatic_Access_Example_XYPoint.ipynb", as_version=4)
nb.metadata.pop("widgets", None)

nbformat.write(nb, "TEMPO_Image_Service_Programmatic_Access_Example_XYPoint.ipynb")
